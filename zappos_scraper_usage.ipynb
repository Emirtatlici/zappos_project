# %%
from zappos_scraper import ZapposScraper
import pandas as pd
pd.set_option("display.max_column",100)

# %%
scraper = ZapposScraper()
start_page = 1
end_page = 5
gender = input("Enter gender (Mandatory.): ")#men and women 
category = input("Enter category (optional - shoes, accessories, or clothing,if you leave it blank it will include all categories.): ")
data = scraper.fetch_data(start_page, end_page, gender, category)
# Out:
# 2024-07-12 19:41:04,814 - zappos_scraper - INFO - Page 1 fetched successfully. 4 pages left.
# 2024-07-12 19:41:08,982 - zappos_scraper - INFO - Page 2 fetched successfully. 3 pages left.
# 2024-07-12 19:41:11,615 - zappos_scraper - INFO - Page 3 fetched successfully. 2 pages left.
# 2024-07-12 19:41:14,214 - zappos_scraper - INFO - Page 4 fetched successfully. 1 pages left.
# 2024-07-12 19:41:17,242 - zappos_scraper - INFO - Page 5 fetched successfully. 0 pages left.

# %%
data.head()
# Out:
#   originalPrice  color  colorId  reviewRating                   productName  \
# 0       $128.00   Blue   655335           0.0      Bahama Coast Washed Away
# 1       $118.00   Blue   748165           0.0      New Coasta Vera Half Zip
# 2       $138.00   Blue   727054           0.0            Montserrat 1/2 Zip
# 3       $165.00  Black        3           0.0         Parker 7" Swim Shorts
# 4        $55.00  Black        3           0.0  Voltripper 20" Hybrid Shorts
#
#   thumbnailImageUrl  reviewCount  styleId    price   msaImageId onSale  \
# 0              None            0  6446598   $72.02  81pvLMv56vL   true
# 1              None            0  6446599   $74.34  71yFFImOAyL   true
# 2              None            0  6382560  $103.50  71NufY-8kjL   true
# 3              None            0  5807093  $127.05  61X3YYW0gFL   true
# 4              None            0  6106348   $53.17  61QZb6Sc4YL   true
#
#    productRating     brandName productId percentOff  \
# ...
